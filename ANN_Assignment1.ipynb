# %% [markdown]
# <a href="https://colab.research.google.com/github/oprostep/2023-fall_LP/blob/main/ANN_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt

targetUrl = "https://raw.githubusercontent.com/gundaminpde/2022/main/sonar3.csv"

### Data_set은 옆에 주소에서 가지고 왔어요. https://github.com/gundaminpde/2022/blob/main/sonar3.csv

Data_set = pd.read_csv(targetUrl, sep=',')

## 전체 Data_set의 전체 형태는 어떤가? 207 rows × 61 columns 구나! column은 0, 1, 2, ..., 60까지.
print(Data_set.shape)

## 전체 Data_set의 앞에 5개 어떤 것인가?
Data_set.head()
# Out:
# (207, 61)
#      0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167   0.018  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#     0.009  0.0032  0
# 0  0.0052  0.0044  0
# 1  0.0095  0.0078  0
# 2  0.0040  0.0117  0
# 3  0.0107  0.0094  0
# 4  0.0051  0.0062  0
#
# [5 rows x 61 columns]

# %%
## 돌과 광물을 특징으로 부터 구분하는 것이다.
## 입력 Data 부분은 0번부터 59번까지의 특징, 정답은 60번에 있다.이제 X와 y로 구분하자.
## 0 과 1이 한개는 암석, 한개는 광물이다. 그런데, 뭐가 무엇인지는 까먹었다.


X = Data_set.iloc[:,0:60]
y = Data_set.iloc[:,60]

# %%
X.head()
# Out:
#      0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167   0.018  \
# 0  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 1  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 2  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 3  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
# 4  0.3039  ...  0.0104  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057
#
#    0.0084   0.009  0.0032
# 0  0.0049  0.0052  0.0044
# 1  0.0164  0.0095  0.0078
# 2  0.0044  0.0040  0.0117
# 3  0.0048  0.0107  0.0094
# 4  0.0027  0.0051  0.0062
#
# [5 rows x 60 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: 0, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

stand = StandardScaler()
X_train = stand.fit_transform(X_train)
X_test = stand.transform(X_test)

def model_fn():
    model = Sequential([
    Dense(30, activation = 'relu', input_shape = (X_train.shape[1],)),
    Dense(10, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
    return model

model = model_fn()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=3, verbose=1)
history = model.fit(X_train, y_train, epochs=30, validation_data = (X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/30
# 6/6 [==============================] - 1s 28ms/step - loss: 0.8109 - accuracy: 0.4848 - val_loss: 0.7716 - val_accuracy: 0.5238
# Epoch 2/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7028 - accuracy: 0.5394 - val_loss: 0.6760 - val_accuracy: 0.5476
# Epoch 3/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6289 - accuracy: 0.6485 - val_loss: 0.6068 - val_accuracy: 0.7143
# Epoch 4/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5750 - accuracy: 0.6848 - val_loss: 0.5572 - val_accuracy: 0.6667
# Epoch 5/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5334 - accuracy: 0.7455 - val_loss: 0.5201 - val_accuracy: 0.7857
# Epoch 6/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5000 - accuracy: 0.7697 - val_loss: 0.4904 - val_accuracy: 0.8095
# Epoch 7/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4707 - accuracy: 0.7879 - val_loss: 0.4678 - val_accuracy: 0.8095
# Epoch 8/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4454 - accuracy: 0.8121 - val_loss: 0.4472 - val_accuracy: 0.8333
# Epoch 9/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4212 - accuracy: 0.8242 - val_loss: 0.4351 - val_accuracy: 0.8333
# Epoch 10/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4005 - accuracy: 0.8424 - val_loss: 0.4226 - val_accuracy: 0.8333
# Epoch 11/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3809 - accuracy: 0.8606 - val_loss: 0.4081 - val_accuracy: 0.8571
# Epoch 12/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.8606 - val_loss: 0.3968 - val_accuracy: 0.8571
# Epoch 13/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3440 - accuracy: 0.8727 - val_loss: 0.3876 - val_accuracy: 0.8571
# Epoch 14/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3281 - accuracy: 0.8727 - val_loss: 0.3790 - val_accuracy: 0.8571
# Epoch 15/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3124 - accuracy: 0.8909 - val_loss: 0.3699 - val_accuracy: 0.8810
# Epoch 16/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2979 - accuracy: 0.9091 - val_loss: 0.3620 - val_accuracy: 0.8571
# Epoch 17/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2850 - accuracy: 0.8970 - val_loss: 0.3612 - val_accuracy: 0.8333
# Epoch 18/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2722 - accuracy: 0.8970 - val_loss: 0.3573 - val_accuracy: 0.8333
# Epoch 19/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2601 - accuracy: 0.9091 - val_loss: 0.3536 - val_accuracy: 0.8095
# Epoch 20/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2483 - accuracy: 0.9212 - val_loss: 0.3512 - val_accuracy: 0.8095
# Epoch 21/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2366 - accuracy: 0.9212 - val_loss: 0.3493 - val_accuracy: 0.8095
# Epoch 22/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2259 - accuracy: 0.9273 - val_loss: 0.3463 - val_accuracy: 0.8095
# Epoch 23/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2158 - accuracy: 0.9394 - val_loss: 0.3421 - val_accuracy: 0.8095
# Epoch 24/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2056 - accuracy: 0.9394 - val_loss: 0.3394 - val_accuracy: 0.8095
# Epoch 25/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.9455 - val_loss: 0.3345 - val_accuracy: 0.8571
# Epoch 26/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1873 - accuracy: 0.9515 - val_loss: 0.3352 - val_accuracy: 0.8095
# Epoch 27/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1787 - accuracy: 0.9515 - val_loss: 0.3356 - val_accuracy: 0.8095
# Epoch 28/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1703 - accuracy: 0.9515 - val_loss: 0.3387 - val_accuracy: 0.8095
# Epoch 28: early stopping

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c="red", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
